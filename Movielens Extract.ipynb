# %%
import pandas as pd

# %%
kaggle_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
kaggle_metadata.sample(5)
# Out:
#        adult belongs_to_collection    budget  \
# 9419   False                   NaN  14000000
# 12330  False                   NaN  15000000
# 31489  False                   NaN         0
# 23266  False                   NaN         0
# 45037  False                   NaN         0
#
#                                                   genres homepage      id  \
# 9419   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      NaN   12542
# 12330  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      NaN   24624
# 31489                      [{'id': 80, 'name': 'Crime'}]      NaN  134679
# 23266                      [{'id': 18, 'name': 'Drama'}]      NaN   89547
# 45037  [{'id': 36, 'name': 'History'}, {'id': 35, 'na...      NaN   77519
#
#          imdb_id original_language      original_title  \
# 9419   tt0357474                en  Belly of the Beast
# 12330  tt0345461                en       The Detonator
# 31489  tt0075109                it  Pronto ad uccidere
# 23266  tt0045578                en         Bright Road
# 45037  tt0214878                fr         Le libertin
#
#                                                 overview  ... release_date  \
# 9419   Jake and Sunti go to meet Mongkol, the leader ...  ...   2003-12-30
# 12330  Sonni Griffith, a top US Secret Agent must pro...  ...   2006-04-25
# 31489  Ray Lovelock stars as Massimo, a young underco...  ...   1976-10-08
# 23266  Based on the story, "See How They Run," which ...  ...   1953-04-17
# 45037  French philosopher Denis Diderot produces the ...  ...   2000-03-15
#
#       revenue runtime                                   spoken_languages  \
# 9419      0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 12330     0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 31489     0.0    94.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 23266     0.0    68.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 45037     0.0   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
#
#          status                         tagline               title  video  \
# 9419   Released  A Father's Rage Knows No Limit  Belly of the Beast  False
# 12330  Released                             NaN       The Detonator  False
# 31489  Released                             NaN    Meet Him And Die  False
# 23266  Released                             NaN         Bright Road  False
# 45037  Released                             NaN       The Libertine  False
#
#       vote_average vote_count
# 9419           4.8       38.0
# 12330          4.2       30.0
# 31489          5.0        1.0
# 23266          6.3        3.0
# 45037          6.4        4.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 21481756  223146    40339     3.5  1493020463
# 4616021    47391    49274     1.5  1491445299
# 7607345    78577     2617     3.0   939770146
# 24615997  255859     2908     5.0   979329603
# 14699058  152810     5792     4.0  1041863653
